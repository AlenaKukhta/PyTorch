# %% [markdown]
# # Практическое задание к уроку 8. Attention Transformer
#
# Переписать загрузку данных с python функций на Dataset и Dataloader и применить сеть с attention

# %%
# !pip install facenet_pytorch
# Out:
# Requirement already satisfied: facenet_pytorch in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (2.5.2)
# Requirement already satisfied: requests in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from facenet_pytorch) (2.26.0)
# Requirement already satisfied: torchvision in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from facenet_pytorch) (0.11.3)
# Requirement already satisfied: numpy in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from facenet_pytorch) (1.20.3)
# Requirement already satisfied: pillow in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from facenet_pytorch) (8.4.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from requests->facenet_pytorch) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from requests->facenet_pytorch) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from requests->facenet_pytorch) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from requests->facenet_pytorch) (2021.10.8)
# Requirement already satisfied: torch==1.10.2 in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from torchvision->facenet_pytorch) (1.10.2)
# Requirement already satisfied: typing-extensions in /Users/alenakukhta/opt/anaconda3/lib/python3.9/site-packages (from torch==1.10.2->torchvision->facenet_pytorch) (3.10.0.2)

# %%
import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as tt
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline
import time
from torch.autograd import Variable
import pandas as pd
from PIL import Image
import random
from matplotlib import image
import shutil
from sklearn.model_selection import train_test_split
import cv2
from facenet_pytorch import MTCNN
from IPython import display
from sklearn.metrics import accuracy_score

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
transforms = tt.Compose([tt.Grayscale(num_output_channels=1), tt.CenterCrop(240), tt.Resize(64), tt.ToTensor()])
for folder in os.listdir('leapGestRecog'):
    images = ImageFolder(os.path.join('leapGestRecog', folder), transforms)

# %%
images
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2000
#     Root location: leapGestRecog/06
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                CenterCrop(size=(240, 240))
#                Resize(size=64, interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#            )

# %%
X_train, X_test = train_test_split(images, test_size = 0.3, random_state = 42)

# %%
train_data_loader = DataLoader(X_train, batch_size=32, shuffle=True)
test_data_loader = DataLoader(X_test, batch_size=16)

# %%
def showbatch(batch):
    for images, labels in batch:
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.set_xticks([]); ax.set_yticks([])
        print(images[0].shape)
        ax.imshow(make_grid(images[:64], nrow=8).permute(1, 2, 0))
        break

showbatch(train_data_loader)
# Out:
# torch.Size([1, 64, 64])

# %%
class Hand_Classifier(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.conv1 = self.conv_block(1, 32, pool=False)
        self.conv2 = self.conv_block(32, 32, pool=True)
        self.conv3 = self.conv_block(32, 64, pool=True)
        self.drop = nn.Dropout(0.3)
        self.dense = nn.Sequential(nn.Flatten(), 
                                   nn.Linear(64*6*6, 256), 
                                   nn.ReLU(inplace=True), 
                                   nn.Linear(256, 10), 
                                   nn.Softmax(dim=1)
                                  )
        
    @staticmethod
    def conv_block(in_feat, out_feat, pool=False):
        layers = [nn.Conv2d(in_feat, out_feat, kernel_size=3), nn.ReLU(inplace=True)]
        if pool:
            layers.append(nn.MaxPool2d(kernel_size=3))
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.drop(out)
        out = self.conv3(out)
        out = self.drop(out)
        out = self.dense(out)
        
        return out

# %%
def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
def accuracy(pred, true):
    pred = np.argmax(pred.to('cpu').detach().numpy(), axis=1)
    true = true.to('cpu').detach().numpy()
    return len(np.where(pred==true)[0])/len(true)

# %%
hс = Hand_Classifier()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(hс.parameters(), lr=0.001, weight_decay=1e-6)

# %%
hс.to(device)
# Out:
# Hand_Classifier(
#   (conv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   )
#   (drop): Dropout(p=0.3, inplace=False)
#   (dense): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2304, out_features=256, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#     (4): Softmax(dim=1)
#   )
# )

# %%
train_loss_history = []
accuracy_history = []

for epoch in range(40):
    epoch_accuracy = []
    epoch_loss = []
    for images, labels in train_data_loader:
        
        images = images.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        
        outputs = hс(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss.append(loss.item())
        epoch_accuracy.append(accuracy(outputs, labels))
    
    train_loss_history.append(np.mean(epoch_loss))
    accuracy_history.append(np.mean(epoch_accuracy))
    print(f'Epoch {epoch+1}, loss: {np.mean(epoch_loss)}, accuracy: {np.mean(epoch_accuracy)}')
# Out:
# Epoch 1, loss: 2.216221194375645, accuracy: 0.22703598484848486
# Epoch 2, loss: 1.7724374695257707, accuracy: 0.6953125
# Epoch 3, loss: 1.6660796837373213, accuracy: 0.7985321969696969
# Epoch 4, loss: 1.6453669342127712, accuracy: 0.8186553030303031
# Epoch 5, loss: 1.6403941864317113, accuracy: 0.8205492424242423
# Epoch 6, loss: 1.6219598217443987, accuracy: 0.8413825757575758
# Epoch 7, loss: 1.5998728464950214, accuracy: 0.8619791666666667
# Epoch 8, loss: 1.5869911177591844, accuracy: 0.8768939393939394
# Epoch 9, loss: 1.564694502136924, accuracy: 0.8982007575757577
# Epoch 10, loss: 1.5621341981671073, accuracy: 0.8998579545454546
# Epoch 11, loss: 1.5656176697124133, accuracy: 0.8970170454545454
# Epoch 12, loss: 1.568679538640109, accuracy: 0.8925189393939394
# Epoch 13, loss: 1.5641341236504642, accuracy: 0.8974905303030304
# Epoch 14, loss: 1.5708269503983585, accuracy: 0.8913352272727273
# Epoch 15, loss: 1.5576623434370214, accuracy: 0.9034090909090909
# Epoch 16, loss: 1.5577442889863795, accuracy: 0.902935606060606
# Epoch 17, loss: 1.5626332543113015, accuracy: 0.8982007575757577
# Epoch 18, loss: 1.5572988228364424, accuracy: 0.9031723484848485
# Epoch 19, loss: 1.5608878758820621, accuracy: 0.8998579545454546
# Epoch 20, loss: 1.5596525506539778, accuracy: 0.9019886363636364
# Epoch 21, loss: 1.560351547869769, accuracy: 0.9010416666666667
# Epoch 22, loss: 1.559624197808179, accuracy: 0.9012784090909091
# Epoch 23, loss: 1.5561608590862968, accuracy: 0.9045928030303031
# Epoch 24, loss: 1.5537527149373835, accuracy: 0.90625
# Epoch 25, loss: 1.5597905028950085, accuracy: 0.9012784090909091
# Epoch 26, loss: 1.5576405687765642, accuracy: 0.9038825757575758
# Epoch 27, loss: 1.556049731644717, accuracy: 0.9041193181818182
# Epoch 28, loss: 1.5088051124052568, accuracy: 0.9509943181818182
# Epoch 29, loss: 1.4777594073252245, accuracy: 0.9850852272727273
# Epoch 30, loss: 1.4749920259822498, accuracy: 0.9857954545454546
# Epoch 31, loss: 1.4718710021539168, accuracy: 0.9893465909090909
# Epoch 32, loss: 1.477952927350998, accuracy: 0.984375
# Epoch 33, loss: 1.4768474102020264, accuracy: 0.9865056818181818
# Epoch 34, loss: 1.475006872957403, accuracy: 0.9865056818181818
# Epoch 35, loss: 1.4740902971137653, accuracy: 0.9867424242424242
# Epoch 36, loss: 1.4789077260277488, accuracy: 0.9815340909090909
# Epoch 37, loss: 1.474015235900879, accuracy: 0.987689393939394
# Epoch 38, loss: 1.4786577251824466, accuracy: 0.9834280303030304
# Epoch 39, loss: 1.4704953215338967, accuracy: 0.9912405303030304
# Epoch 40, loss: 1.473010092973709, accuracy: 0.9886363636363636

# %%
import os
import cv2
import torch
import numpy as np
from facenet_pytorch import MTCNN

mtcnn = MTCNN()

def _draw(frame, boxes):
    try:
        for box in boxes:
            # Рисуем обрамляющий прямоугольник лица на кадре
            cv2.rectangle(frame,
                          (box[0], box[1]),
                          (box[2], box[3]),
                          (0, 0, 255),
                          thickness=2)
    except:
        print('Something wrong im draw function!')
    return frame

def digit_to_classname(digit):
    if digit == 0:
        return 'palm'
    elif digit == 1:
        return 'l'
    elif digit == 2:
        return 'fist'
    elif digit == 3:
        return 'fist_moved'
    elif digit == 4:
        return 'thumb'
    elif digit == 5:
        return 'index'
    elif digit == 6:
        return 'ok'
    elif digit == 7:
        return 'palm_moved'
    elif digit == 8:
        return 'c'
    elif digit == 9:
        return 'down'

def crop_faces(frame, boxes):
    faces = []
    for i, box in enumerate(boxes):
        faces.append(frame[int(box[1]):int(box[3]), 
            int(box[0]):int(box[2])])
    return faces
    
flag_face = "Face not detected"

while True:
    cap = cv2.VideoCapture(0) 
    ret, frame = cap.read() 
    
    boxes, probs, landmarks = mtcnn.detect(frame, landmarks=True)
    
    if np.all(boxes):
        # Рисуем на кадре
        frame = _draw(frame, boxes)
        flag_face = "Face detected"
    else:
        flag_face = 'Face not detected' 
        
    if flag_face == "Face detected":
    
        cv2.rectangle(frame, (0,0), (250, 250), (0, 0, 255), thickness=2)
        hand = crop_faces(frame, [[0,0, 250, 250]])[0]

        hand = cv2.resize(hand, (64, 64))
        hand = cv2.cvtColor(hand, cv2.COLOR_BGR2GRAY)    
        
        #th, dframe = cv2.threshold(hand, 0, 255)
        
        torch_hand = torch.from_numpy(hand).unsqueeze(0).to(device).float()
        #torch_hand = torch.from_numpy(dframe).unsqueeze(0).to(device).float()
        gesture_probs = hс(torch_hand[None, ...])
    
    
    cv2.imshow('Face Detection', frame) 
    
    display.clear_output(wait=False)    
    print(flag_face)    
    if flag_face == "Face detected":
        print(digit_to_classname(gesture_probs.argmax()))
        plt.imshow(torch.tensor(torch_hand.detach().cpu().numpy()[0,:,:]))    
    display.display(plt.gcf())
    
    
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
# Очищаем все объекты opencv, что мы создали
self.cap.release()
cv2.destroyAllWindows()
# Out:
# Face not detected
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/64/g6jhnpm16ql1vgrrbrbd_yd00000gn/T/ipykernel_12361/3019764905.py in <module>
#      55     ret, frame = cap.read()
#      56
# ---> 57     boxes, probs, landmarks = mtcnn.detect(frame, landmarks=True)
#      58
#      59     if np.all(boxes):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/facenet_pytorch/models/mtcnn.py in detect(self, img, landmarks)
#     311
#     312         with torch.no_grad():
# --> 313             batch_boxes, batch_points = detect_face(
#     314                 img, self.min_face_size,
#     315                 self.pnet, self.rnet, self.onet,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/facenet_pytorch/models/utils/detect_face.py in detect_face(imgs, minsize, pnet, rnet, onet, threshold, factor, device)
#     109         for k in range(len(y)):
#     110             if ey[k] > (y[k] - 1) and ex[k] > (x[k] - 1):
# --> 111                 img_k = imgs[image_inds[k], :, (y[k] - 1):ey[k], (x[k] - 1):ex[k]].unsqueeze(0)
#     112                 im_data.append(imresample(img_k, (24, 24)))
#     113         im_data = torch.cat(im_data, dim=0)
#
# KeyboardInterrupt:

# %%
cap = cv2.VideoCapture(0) 
ret, frame = cap.read() 

#th, dframe = cv2.threshold(dframe, 30, 255, cv2.THRESH_BINARY)

cv2.rectangle(frame, (0,0), (250, 250), (0, 0, 255), thickness=2)
hand = crop_faces(frame, [[0,0, 250, 250]])[0]

hand = cv2.resize(hand, (64, 64))
hand = cv2.cvtColor(hand, cv2.COLOR_BGR2GRAY)  
th, dframe = cv2.threshold(hand, 30, 255, cv2.THRESH_BINARY)

torch_hand = torch.from_numpy(dframe).unsqueeze(0).to(device).float()
gesture_probs = hс(torch_hand[None, ...])



plt.imshow(torch.tensor(torch_hand.detach().cpu().numpy()[0,:,:]))
plt.show()

# %%
cap.release()
cv2.destroyAllWindows()
